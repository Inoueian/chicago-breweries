# %% [markdown]
# This notebook gets the Untappd URL for each brewery in brews/breweries_final.csv.

# %%
import pandas as pd
from time import sleep

import requests
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %% [markdown]
# ### Import brewery database

# %%
dfBrewery = pd.read_csv('brews/breweries_final.csv')

# %%
dfBrewery.head()
# Out:
#   brewID                        brewery              address          city  \
# 0   1hd3  18th Street Brewery – Hammond  5417 N. Oakley Ave.       Hammond
# 1   1hy5     18th Street Brewery – Gary     5725 Miller Ave.          Gary
# 2   2W.3            25 West Brewing Co.      2 Stratford Dr.  Bloomingdale
# 3   3 .2                350 Brewing Co.    7144 W. 183rd St.   Tinley Park
# 4   3l.6           3 Floyds Brewing Co.   9750 Indiana Pkwy.       Munster
#
#   state neighborhood                               website  \
# 0    IN          NaN     http://www.18thstreetbrewery.com/
# 1    IN          NaN     http://www.18thstreetbrewery.com/
# 2    IL          NaN  https://www.facebook.com/25WestBrew/
# 3    IL          NaN                https://350brewing.com
# 4    IN          NaN               http://www.3floyds.com/
#
#                features                 coord       coord2 inChicago  \
# 0        kitchen & beer    -87.517525,41.6156   98416802.0        no
# 1        kitchen & beer   -87.26886,41.599365   98428122.0        no
# 2                   NaN   -88.11923,41.950455  112710728.0        no
# 3        kitchen & beer   -87.791595,41.55857  638598086.0        no
# 4  kitchen & beer, tour  -87.515755,41.536514   98443594.0        no
#
#     latitude  longitude hasTapRoom hasTour hasKitchen
# 0  41.615600 -87.517525         no      no        yes
# 1  41.599365 -87.268860         no      no        yes
# 2  41.950455 -88.119230         no      no         no
# 3  41.558570 -87.791595         no      no        yes
# 4  41.536514 -87.515755         no     yes        yes

# %%
dfBrewery['brewery']
# Out:
# 0           18th Street Brewery – Hammond
# 1              18th Street Brewery – Gary
# 2                     25 West Brewing Co.
# 3                         350 Brewing Co.
# 4                    3 Floyds Brewing Co.
# 5                     5 Rabbit Cervecería
# 6                       51st Ward Brewing
# 7                    9th Hour Brewing Co.
# 8                    All Rise Brewing Co.
# 9                Afterthought Brewing Co.
# 10                      Alter Brewing Co.
# 11                  Andersonville Brewing
# 12                    Ancient Owl Brewing
# 13                          ALULU Brewpub
# 14                                 Aleman
# 15             Arrowhead Ales Brewing Co.
# 16                       Alarmist Brewing
# 17               Around the Bend Beer Co.
# 18                          Argus Brewery
# 19                      Byway Brewing Co.
# 20                    Bosacki's Home Brew
# 21                BBGB Brewery & Hop Farm
# 22              Black Horizon Brewing Co.
# 23                        Band of Bohemia
# 24                  Bold Dog Beer Company
# 25                Blue Island Brewing Co.
# 26                              Baderbräu
# 27                      Blue Nose Brewery
# 28                  Buffalo Creek Brewing
# 29                    Banging Gavel Brews
#                       ...
# 163                          Saint Errant
# 164                     Stupid Hare Brews
# 165            Scorched Earth Brewing Co.
# 166                Short Fuse Brewing Co.
# 167                    Sketchbook Brewing
# 168                      Spiteful Brewing
# 169       The Devil's Trumpet Brewing Co.
# 170               Two Brothers Roundhouse
# 171                  Two Brothers Brewing
# 172                    Ten Ninety Brewing
# 173                        The Lucky Monk
# 174                       Tribes Alehouse
# 175                 Tighthead Brewing Co.
# 176              Trail's Edge Brewing Co.
# 177                   Temperance Beer Co.
# 178             Twisted Hippo Brewing Co.
# 179    Une Année / Hubbard's Cave Brewery
# 180                 Urban Renewal Brewery
# 181                 Vice District Brewing
# 182                  Veteran Beer Company
# 183      Village Vintner Winery & Brewery
# 184                      Windmill Brewing
# 185                      Wildrose Brewing
# 186              Wild Onion Pub & Brewery
# 187                       Wolfden Brewing
# 188             Woggly Square Brewing Co.
# 189                            Werk Force
# 190               Will County Brewing Co.
# 191                        Whiner Brewery
# 192                               ZümBier
# Name: brewery, Length: 193, dtype: object

# %% [markdown]
# ### Scraping Untappd

# %%
def simpleGet(url):
    """Attempts to get the content at 'url' by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None"""
    try:
        with closing(requests.get(url, stream=True)) as resp:
            if isGoodResponse(resp):
                return resp.content
            else:
                return None
    
    except RequestException as e:
        logError('Error during requests to {0} : {1}'.format(url, str(e)))
        return None
    
def isGoodResponse(resp):
    """Returns True if the response seems to be HTML"""
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200
            and content_type is not None
            and content_type.find('html') > -1)

def logError(e):
    """Prints error"""
    print(e)

# %%
def makeSoup(url):
    """Use simple_get function to make soup from url"""
    try:
        return BeautifulSoup(simpleGet(url), 'html.parser')
    except TypeError as e:
        logError('Non-HTML content at {0} : {1}'.format(url, str(e)))
        return None

# %% [markdown]
# Make functions that takes us from brewery name to brewery search page to brewery page.

# %%
#Make a dict to treat exceptional cases.
#Breweries not yet on Untappd are mapped to '',
#and others are breweries that need alternative search terms.
nameDict = {'Aleman': 'Aleman Brewing',
            'Bixi Brewery': '',
            'Crown Brewing': 'Crown Brewing Company',
            'Englewood Brews': '',
            'FIBS Brewing': '',
            'Lake Effect Brewing Co.': 'Lake Effect Brewing',
            'McHenry Brewing Company': "Chain O'Lakes Brewing Company",
            'Oak Park Brewing Co.': 'Oak Park Brewing Company (IL)',
            'Strike Ten Brewing Co.': '',
            'Scallywag Brewing': '',
            'Whiner Brewery': ''
            }

# %%
test = '–'

# %%
test.encode()
# Out:
# b'\xe2\x80\x93'

# %%
str(b'\xe2\x80\x93')
# Out:
# "b'\\xe2\\x80\\x93'"

# %%
def searchURL(name):
    """Returns the URL to search Untappd for brewery"""
    #remove parts after '–', replace ' ' by '+'
    nameParsed = name.split(sep='–')[0].strip().replace(' ', '+')
    return 'https://untappd.com/search?q=' + nameParsed + '&type=brewery'

def getBreweryURL(name):
    """Returns the Untappd brewery page URL from name"""
    if name == '': #recursion did not work
        return None
    elif name in nameDict: #convert exceptional cases
        name = nameDict[name]
        
    try:
        url = searchURL(name)
        soup = makeSoup(url)
        #get the result part of the HTML
        result = soup.find("div", {"class": "results-container"})
        #go to the top brewery in the search
        nameTag = result.find("p", {"class": "name"})
        #get the href
        href = name.find("a")['href']
        return 'https://untappd.com' + href
    except AttributeError: #no search result
        #try without the last word (recursion)
        shorterName = ' '.join(name.split()[:-1])
        return getBreweryURL(shorterName)

# %% [markdown]
# I need to log in. Define logged in versions of the above functions.

# %%
def getSessionKey(session):
    """Get session key from the Untappd login page."""
    login = session.get('http://untappd.com/login')
    soup  = BeautifulSoup(login.content, 'html.parser')
    form  = soup.find('form')
    return form.find('input', attrs={'name': 'session_key'})['value']

# %%
def simpleGetL(url, session):
    """Attempts to get the content at 'url' by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None"""
    try:
        with closing(session.get(url, stream=True)) as resp:
            if isGoodResponse(resp):
                return resp.content
            else:
                return None
    
    except RequestException as e:
        logError('Error during requests to {0} : {1}'.format(url, str(e)))
        return None
    
def makeSoupL(url, session):
    """Use simple_get function to make soup from url"""
    try:
        return BeautifulSoup(simpleGetL(url, session), 'html.parser')
    except TypeError as e:
        logError('Non-HTML content at {0} : {1}'.format(url, str(e)))
        return None

def getBreweryURLL(name, session):
    """Returns the Untappd brewery page URL from name"""
    if name == '': #recursion did not work
        return None
    elif name in nameDict: #convert exceptional cases
        name = nameDict[name]
        
    try:
        url = searchURL(name)
        soup = makeSoupL(url, session)
        #get the result part of the HTML
        result = soup.find("div", {"class": "results-container"})
        #go to the top brewery in the search
        nameTag = result.find("p", {"class": "name"})
        #get the href
        href = nameTag.find("a")['href']
        return 'https://untappd.com' + href
    except AttributeError: #no search result
        #try without the last word (recursion)
        shorterName = ' '.join(name.split()[:-1])
        return getBreweryURLL(shorterName, session)

# %%
import ast

with open('/Users/satoru/untappdLogin.txt', 'r') as f:
    untappdDict = ast.literal_eval(f.read())

# %%
untappdURLDict = {}

with requests.session() as s:
    untappdDict['session_key'] = getSessionKey(s)
    p = s.post('https://untappd.com/login/', data=untappdDict)
    for name in dfBrewery['brewery']:
        sleep(5.)
        untappdURL = getBreweryURLL(name, s)
        print(name, untappdURL)
        untappdURLDict[name] = untappdURL
# Out:
# 18th Street Brewery – Hammond https://untappd.com/18thStreetBrewery
# 18th Street Brewery – Gary https://untappd.com/18thStreetBrewery
# 25 West Brewing Co. https://untappd.com/w/25-west-brewing-co/391402
# 350 Brewing Co. https://untappd.com/350Brewing
# 3 Floyds Brewing Co. https://untappd.com/3floyds
# 5 Rabbit Cervecería https://untappd.com/5Rabbit
# 51st Ward Brewing https://untappd.com/51stWardBeer
# 9th Hour Brewing Co. https://untappd.com/9thHourBrewing
# All Rise Brewing Co. https://untappd.com/AllRiseBrewing
# Afterthought Brewing Co. https://untappd.com/AfterthoughtBrewing
# Alter Brewing Co. https://untappd.com/AlterBrewing_Company
# Andersonville Brewing https://untappd.com/AndersonvilleBrewing
# Ancient Owl Brewing https://untappd.com/AncientOwlBrewing
# ALULU Brewpub https://untappd.com/ALULUBrewPub
# Aleman https://untappd.com/Aleman
# Arrowhead Ales Brewing Co. https://untappd.com/ArrowheadAles
# Alarmist Brewing https://untappd.com/AlarmistBrewing
# Around the Bend Beer Co. https://untappd.com/ATB
# Argus Brewery https://untappd.com/ArgusBrewery
# Byway Brewing Co. https://untappd.com/BywayBrewingCompany
# Bosacki's Home Brew https://untappd.com/BosackisHomeBrew
# BBGB Brewery & Hop Farm https://untappd.com/BBGBBreweryHopFarm
# Black Horizon Brewing Co. https://untappd.com/BlackHorizonBrewingCompany
# Band of Bohemia https://untappd.com/w/band-of-bohemia/201836
# Bold Dog Beer Company https://untappd.com/BoldDogBeerCo
# Blue Island Brewing Co. https://untappd.com/w/blue-island-beer-company/120917
# Baderbräu https://untappd.com/baderbrau
# Blue Nose Brewery https://untappd.com/BlueNoseAdmin
# Buffalo Creek Brewing https://untappd.com/BuffaloCreekBrewing
# Banging Gavel Brews https://untappd.com/bangingavel
# Berghoff Brewery https://untappd.com/BerghoffBeer
# Bixi Brewery None
# BuckleDown Brewing https://untappd.com/BuckleDownBrewing
# Bucket List Brewing https://untappd.com/BucketListBrewingCompany
# Bulldog Brewing Co. https://untappd.com/BulldogBrewingCoIndiana
# Ballast Point https://untappd.com/BallastPoint
# Burnt City Brewing – Brewpub https://untappd.com/BurntCity
# Burnt City Brewing https://untappd.com/BurntCity
# Birreria Chicago https://untappd.com/BirreriaEatalyChicago
# Begyle Brewing Co. https://untappd.com/BegyleBrewing
# Chicago Beer Company https://untappd.com/chicagobeerco
# Cademon Brewing Co. https://untappd.com/CademonBrewing
# Cahoots Brewing https://untappd.com/CahootsBrewing
# Church Street Brewing https://untappd.com/ChurchStreetBrewingCo
# Corridor Brewery & Provisions https://untappd.com/CorridorBrewery
# Crystal Lake Brewing https://untappd.com/CrystalLakeBrewery
# Crown Brewing https://untappd.com/crownbrewing
# Cruz Blanca https://untappd.com/CruzBlancaChi
# Dry City Brew Works https://untappd.com/DryCity
# Dovetail Brewery https://untappd.com/DovetailBrewery
# DryHop Brewers https://untappd.com/DryHopBrewers
# D. Litch's Beer https://untappd.com/DLitchsBeer
# Elder Brewing Co. https://untappd.com/ElderBrewing
# Emmett's Brewing Co. – Palatine https://untappd.com/EmmettsBrewingCo
# Emmett's Brewing Co. – Downers Grove https://untappd.com/EmmettsBrewingCo
# Emmett's Brewing Co. – West Dundee https://untappd.com/EmmettsBrewingCo
# Emmett's Brewing Co. – Wheaton https://untappd.com/EmmettsBrewingCo
# Elmhurst Brewing Co. https://untappd.com/ElmhurstBrewingCompany
# Empirical Brewery – Brewpub https://untappd.com/EmpiricalBrewery
# Empirical Brewery https://untappd.com/EmpiricalBrewery
# Evil Horse Brewing Co. https://untappd.com/EvilHorseBrewing
# Englewood Brews None
# Energy City Brewing https://untappd.com/EnergyCityBrewing
# Eris Brewery & Ciderhouse https://untappd.com/Eris_Brewery_And_Cider_House
# Exit Strategy Brewing Co. https://untappd.com/ESBC
# Forbidden Root https://untappd.com/ForbiddenRoot
# Finch Beer Co. https://untappd.com/finchbeer
# Flapjack Brewery https://untappd.com/flapjackbrewery
# Flossmoor Station Brewing Co. https://untappd.com/FlossmoorBrewCo
# Flesk Brewing https://untappd.com/FleskBrewingCompany
# FIBS Brewing None
# Great Central Brewing Co. https://untappd.com/GreatCentralBrewingCompany
# Greenstar Brewing Co. https://untappd.com/GreenstarBrewing
# Granite City Brewery - Naperville https://untappd.com/gcfb
# Granite City Brewery - Schaumburg https://untappd.com/gcfb
# Granite City Brewery - Orland Park https://untappd.com/gcfb
# Gino's East Brewing Co. https://untappd.com/GinosEast
# Goose Island Beer Co. https://untappd.com/gooseisland
# Goose Island Brewhouse https://untappd.com/GooseIslandBrewpubs
# Hop Butcher for the World https://untappd.com/HopButcher
# Hofbräuhaus Chicago https://untappd.com/w/staatliches-hofbra-uhaus-ma-1-4-nchen/5566
# Hopewell Brewing https://untappd.com/HopewellBrewingCo
# Half Day Brewing Co. https://untappd.com/HalfDayBrewing
# Half Acre Beer Co. https://untappd.com/halfacrebeerco
# Half Acre Beer Co. – Taproom https://untappd.com/halfacrebeerco
# Hailstorm Brewing Co. https://untappd.com/HailstormBrewingCo
# Haymarket Pub & Brewery https://untappd.com/haymarket
# Hopothesis Beer Co. https://untappd.com/Hopothesis
# Horse Thief Hollow https://untappd.com/HorseThiefHollowBrewingCo
# Hopvine Brewing Co. https://untappd.com/HopvineBrewingCompany
# Imperial Oak Brewing https://untappd.com/ImperialOakBrewing
# Itasca Brewing Co. https://untappd.com/w/itasca-brewing-company/40906
# Illuminated Brew Works https://untappd.com/ibw666
# Jolly Pumpkin Artisan Ales https://untappd.com/jollypumpkinartisanales
# Kings & Convicts Brewing Co. https://untappd.com/KCBCbeer
# Kinslahger Brewing Co. https://untappd.com/KinslahgerBrewingCompany
# Lunar Brewing Co. https://untappd.com/LunarBrewingCo
# Lake Effect Brewing Co. https://untappd.com/LakeEffectBrewing
# Lake Bluff Brewing Co. https://untappd.com/lakebluffbrewingco
# Light the Lamp Brewery https://untappd.com/LightTheLamp
# Living Proof Brewing https://untappd.com/LivingProofBrewing
# LaGrow Organic Beer Co. https://untappd.com/LaGrowOrganicBeerCo
# Lo Rez Brewing https://untappd.com/LoRezBrewing
# Lagunitas Brewing Co. https://untappd.com/LagunitasBrewingCo
# Metal Monkey Brewing https://untappd.com/MetalMonkeyBrewing
# Middle Brow Beer Co. https://untappd.com/middlebrow
# Moody Tongue Brewing Co. https://untappd.com/MoodyTongue
# More Brewing Co. https://untappd.com/MoreBrewing
# Mikerphone Brewing https://untappd.com/MikerphoneBrewing
# McHenry Brewing Company None
# Myths and Legends Brewing https://untappd.com/UrbanLegendBeer
# Miskatonic Brewing Co. https://untappd.com/MiskatonicBrewingCompany
# Mickey Finn's Brewery https://untappd.com/MickeyFinnsBrewery
# Maplewood Brewery & Distillery https://untappd.com/Maplewood
# Motor Row Brewing https://untappd.com/MotorRowBrewing
# MyGrain Brewing Co. https://untappd.com/MyGrainBrewingCompany
# Metropolitan Brewing https://untappd.com/metrobrewing
# Macushla Brewing Co. https://untappd.com/w/macushla-brewing-co/357382
# Marz Community Brewing https://untappd.com/MarzCommunityBrewing
# New Oberpfalz Brewing https://untappd.com/NewOberpfalzBrewing
# Nevin's Brewing Co. https://untappd.com/Nevins_Brewing_Company
# Noon Whistle Brewing https://untappd.com/NoonWhistle
# Old Irving Brewing Co. https://untappd.com/OldIrvingBrewingCompany
# Oak Park Brewing Co. https://untappd.com/OakParkBrewingCompanyIL
# Off Color Brewing https://untappd.com/OffColorBrewing
# Off Square Brewing https://untappd.com/OffSquareBrewing
# Off Color Mousetrap https://untappd.com/OffColorBrewing
# One Trick Pony Brewery https://untappd.com/w/one-trick-pony/31051
# Oswego Brewing Co. https://untappd.com/OswegoBrewingCo
# Open Outcry Brewing Co. https://untappd.com/OpenOutcryBrew
# On Tour Brewing Co. https://untappd.com/OnTourBrewingCompany
# Only Child Brewing https://untappd.com/onlychildbrewing
# Piece Brewery & Pizzeria https://untappd.com/PieceBrewery
# Pipeworks Brewing Co. https://untappd.com/pipeworksbrewery
# Prairie Krafts Brewing Co. https://untappd.com/PrairieKrafts
# Peckish Pig https://untappd.com/PeckishPig
# Pollyanna Brewing Co. https://untappd.com/PollyannaBrewingCompany
# Pollyanna Brewing Co. - Roselare https://untappd.com/PollyannaBrewingCompany
# Penrose Brewing Co. https://untappd.com/PenroseBrewingCompany
# Pokro Brewing Co. https://untappd.com/PokroBrewingCo
# Present Tense Fine Ales https://untappd.com/PresentTenseFineAles
# Ram Restaurant & Brewery https://untappd.com/theRAM
# Rabid Brewing https://untappd.com/RabidBrewing
# Ravinia Brewing https://untappd.com/RaviniaBrewingCompany
# Rock Bottom – Lombard https://untappd.com/RockBottom
# Rock Bottom – Warrenville https://untappd.com/RockBottom
# Rock Bottom – Bolingbrook https://untappd.com/RockBottom
# Rock Bottom – Orland Park https://untappd.com/RockBottom
# Rock Bottom Restaurant & Brewery https://untappd.com/RockBottom
# Revolution Brewing – Brewpub https://untappd.com/RevolutionBrewingChicago
# Revolution Brewing – Taproom https://untappd.com/RevolutionBrewingChicago
# Roaring Table Brewing https://untappd.com/RoaringTableBrewing
# Stockholm's Brewpub https://untappd.com/w/stockholms/12082
# Side Lot Brewery https://untappd.com/SideLotBrewery
# Solemn Oath Brewery https://untappd.com/solemnoathbeer
# Strike Ten Brewing Co. None
# Scallywag Brewing None
# Sullers Past Brewing https://untappd.com/SullersPast
# Smylie Bros. Brewing https://untappd.com/SmylieBrothersBrewingCompany
# Small Town Brewery https://untappd.com/SmallTownBrewery
# Skeleton Key Brewery https://untappd.com/SkeletonKeyBrewery
# Saint John Malt Brothers Brewing https://untappd.com/SaintJohnMaltBrothers
# Soundgrowler Brewing https://untappd.com/SoundgrowlerBrewingCo
# Saint Errant https://untappd.com/SaintErrant
# Stupid Hare Brews https://untappd.com/StupidHareBrews
# Scorched Earth Brewing Co. https://untappd.com/ScorchedEarthBrewing
# Short Fuse Brewing Co. https://untappd.com/ShortFuseBrewing
# Sketchbook Brewing https://untappd.com/Sketchbook
# Spiteful Brewing https://untappd.com/spitefulbrewing
# The Devil's Trumpet Brewing Co. https://untappd.com/TheDevilsTrumpetBrewery
# Two Brothers Roundhouse https://untappd.com/TwoBrothersBrewing
# Two Brothers Brewing https://untappd.com/TwoBrothersBrewing
# Ten Ninety Brewing https://untappd.com/TenNinetyBrewingCo
# The Lucky Monk https://untappd.com/TheLuckyMonk
# Tribes Alehouse https://untappd.com/TribesBeerCompany
# Tighthead Brewing Co. https://untappd.com/TightheadBrewingCompany
# Trail's Edge Brewing Co. https://untappd.com/TrailsEdgeBrewingCo
# Temperance Beer Co. https://untappd.com/TemperanceBeer
# Twisted Hippo Brewing Co. https://untappd.com/TwistedHippo
# Une Année / Hubbard's Cave Brewery https://untappd.com/uneannee
# Urban Renewal Brewery https://untappd.com/UrbanRenewBrewery
# Vice District Brewing https://untappd.com/ViceDistrictBrewing
# Veteran Beer Company https://untappd.com/VeteranBeerCompany
# Village Vintner Winery & Brewery https://untappd.com/VillageVintner
# Windmill Brewing https://untappd.com/WindmillBrewing
# Wildrose Brewing https://untappd.com/Wildrosebrewing
# Wild Onion Pub & Brewery https://untappd.com/wildonion
# Wolfden Brewing https://untappd.com/WolfdenBrewingCompany
# Woggly Square Brewing Co. https://untappd.com/w/woggly-square-brewing/382879
# Werk Force https://untappd.com/WerkForceBrewingCompany
# Will County Brewing Co. https://untappd.com/WillCountyBrewingCo
# Whiner Brewery None
# ZümBier https://untappd.com/ZumBierBrewer

# %%
dfBrewery['untappdURL'] = dfBrewery['brewery'].apply(lambda x: untappdURLDict[x])

# %%
dfBrewery.loc[dfBrewery['untappdURL'].isna(), 'untappdURL'] = ''

# %%
dfBrewery.to_csv('brews/breweries_final.csv')
